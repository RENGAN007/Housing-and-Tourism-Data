# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

# %%
tour=pd.read_csv('Top Indian Places to Visit.csv')
tour
# Out:
#      Unnamed: 0      Zone           State         City  \
# 0             0  Northern           Delhi        Delhi
# 1             1  Northern           Delhi        Delhi
# 2             2  Northern           Delhi        Delhi
# 3             3  Northern           Delhi        Delhi
# 4             4  Northern           Delhi        Delhi
# ..          ...       ...             ...          ...
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name          Type Establishment Year  \
# 0                      India Gate  War Memorial               1921
# 1                  Humayun's Tomb          Tomb               1572
# 2               Akshardham Temple        Temple               2005
# ...

# %%
coll=['Type','Google review rating','Number of google review in lakhs','Entrance Fee in INR']
tours=tour[coll]
tours
# Out:
#              Type  Google review rating  Number of google review in lakhs  \
# 0    War Memorial                   4.6                              2.60
# 1            Tomb                   4.5                              0.40
# 2          Temple                   4.6                              0.40
# 3      Theme Park                   4.1                              0.27
# 4     Observatory                   4.2                              0.31
# ..            ...                   ...                               ...
# 320        Temple                   4.6                              0.18
# 321          Fort                   4.5                              1.30
# 322        Museum                   4.7                              0.15
# 323        Palace                   4.4                              0.51
# 324        Museum                   4.5                              0.63
#
#      Entrance Fee in INR
# 0                      0
# 1                     30
# ...

# %%
tours = tours[tours['Entrance Fee in INR'] != 0]
tours
# Out:
#             Type  Google review rating  Number of google review in lakhs  \
# 1           Tomb                   4.5                              0.40
# 2         Temple                   4.6                              0.40
# 3     Theme Park                   4.1                              0.27
# 4    Observatory                   4.2                              0.31
# 7           Fort                   4.5                              1.50
# ..           ...                   ...                               ...
# 318       Museum                   4.4                              0.24
# 321         Fort                   4.5                              1.30
# 322       Museum                   4.7                              0.15
# 323       Palace                   4.4                              0.51
# 324       Museum                   4.5                              0.63
#
#      Entrance Fee in INR
# 1                     30
# 2                     60
# ...

# %%
tours=pd.get_dummies(tours,dtype='int')
x=tours.drop(columns=['Entrance Fee in INR'])
y=tours['Entrance Fee in INR']
print(x.shape)
print(y.shape)
# Out:
# (142, 46)
# (142,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.8570203723102836

# %%
model.score(x_test,y_test)
# Out:
# -3.0469331269239416e+26

# %%
from sklearn.linear_model import Lasso
ttl=Lasso(alpha=50,max_iter=100,tol=0.1)
ttl.fit(x_train,y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
ttl.score(x_train,y_train)
# Out:
# 0.3771771546647801

# %%
from sklearn.linear_model import Ridge
model3=Ridge(alpha=50,max_iter=100,tol=0.1)
model3.fit(x_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
model3.score(x_test,y_test)
# Out:
# -1.0703903278767868

# %%
model3.score(x_train,y_train)
# Out:
# 0.05101631742959578
